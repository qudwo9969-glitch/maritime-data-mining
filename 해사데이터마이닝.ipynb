# %% [markdown]
# <a href="https://colab.research.google.com/github/qudwo9969-glitch/maritime-data-mining/blob/main/%ED%95%B4%EC%82%AC%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%A7%88%EC%9D%B4%EB%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# df = pd.read_csv("members.csv")
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/bigdata_analyst_cert/main/part4/ch3/members.csv")

# 1) 결측치가 있는 행 제거 (기본값 axis=0), 밑으로 가# 면서 제거하니, 행을 제거하는 것임.
df = df.dropna()

# 2) 앞에서부터 70% 데이터 슬라이싱
df = df.iloc[:int(len(df)*0.7)]

# 3) 1사분위 값 계산(정수 출력)
print(int(df['f1'].quantile(.25)))
# Out:
# 57
